# %% [markdown]
# # 유전자 발현데이터를 통해 피부암 환자의 사망률을 예측한다

# %%
import numpy as np
import pandas as pd
import scipy
import matplotlib.pyplot as plt
import seaborn as sns

# 노트북 안에서 그래프를 표시하기 위해
# %matplotlib inline

# Window 의 한글 폰트 설정
plt.rc('font',family='Malgun Gothic')
# Mac 의 한글 폰트 설정
# plt.rc('font', family='AppleGothic')

# %%
#데이터 불러오기
data_table= pd.read_csv("counts.txt.bz2", index_col=0)

# %%
# 각 행은 세포의 종류이고 , 인덱스는 유전자의 종류이다


data_table.head()
# Out:
#        00624286-41dd-476f-a63b-d2a5f484bb45  TCGA-FS-A1Z0  TCGA-D9-A3Z1  \
# A1BG                                1272.36        452.96        288.06
# A1CF                                   0.00          0.00          0.00
# A2BP1                                  0.00          0.00          0.00
# A2LD1                                164.38        552.43        201.83
# A2ML1                                 27.00          0.00          0.00
#
#        02c76d24-f1d2-4029-95b4-8be3bda8fdbe  TCGA-EB-A51B  TCGA-D3-A1Q3  \
# A1BG                                 400.11        420.46        877.59
# A1CF                                   1.00          0.00          0.00
# A2BP1                                  0.00          1.00          0.00
# A2LD1                                165.12         95.75        636.63
# A2ML1                                  0.00          8.00          0.00
#
#        TCGA-FR-A44A  TCGA-EE-A17Z  TCGA-D3-A51G  TCGA-D3-A51E  ...  \
# A1BG         402.77        559.20        269.59        586.66  ...
# A1CF           0.00          0.00          0.00          0.00  ...
# A2BP1          0.00          0.00          0.00          0.00  ...
# A2LD1        241.56         30.82        105.44        239.19  ...
# A2ML1          1.00        763.00          0.00          0.00  ...
#
#        TCGA-D9-A149  TCGA-EE-A3AG  TCGA-D9-A4Z2  TCGA-EB-A4OZ  TCGA-EE-A3J4  \
# A1BG         631.78        560.60        846.55        678.00         32.88
# A1CF           0.00          4.00          3.00          0.00          0.00
# A2BP1          0.00          1.00          0.00          0.00          0.00
# A2LD1        218.47        274.45        770.04         71.74         17.00
# A2ML1          3.00          6.00          0.00       1043.00          1.00
#
#        TCGA-FS-A1ZM  TCGA-D3-A5GS  TCGA-EB-A3XF  TCGA-EE-A2GE  \
# A1BG         997.41        256.93        461.60        634.06
# A1CF           0.00          0.00          0.00          1.00
# A2BP1          0.00          0.00          0.00          2.00
# A2LD1        194.26        156.81         84.35        242.01
# A2ML1        852.00          4.00        587.00          0.00
#
#        ff7431a9-243a-4651-80bb-096379925bbe
# A1BG                                 530.36
# A1CF                                   0.00
# A2BP1                                  1.00
# A2LD1                                377.03
# A2ML1                                  2.00
#
# [5 rows x 375 columns]

# %%
#샘플정보와 유전정보 길이 데이터가 필요하다

samples=list(data_table.columns)
samples
# Out:
# ['00624286-41dd-476f-a63b-d2a5f484bb45',
#  'TCGA-FS-A1Z0',
#  'TCGA-D9-A3Z1',
#  '02c76d24-f1d2-4029-95b4-8be3bda8fdbe',
#  'TCGA-EB-A51B',
#  'TCGA-D3-A1Q3',
#  'TCGA-FR-A44A',
#  'TCGA-EE-A17Z',
#  'TCGA-D3-A51G',
#  'TCGA-D3-A51E',
#  'TCGA-EE-A3AD',
#  'TCGA-ER-A19J',
#  'TCGA-D3-A5GU',
#  'TCGA-FS-A4FD',
#  'TCGA-ER-A2ND',
#  'TCGA-FS-A1ZD',
#  'TCGA-EE-A2M6',
#  '0e4d53ba-dd42-41b7-bcfe-ff8b9b5dab07',
#  'TCGA-EE-A2GN',
#  'TCGA-EE-A29V',
#  '10f253bd-1cdd-4515-a7fa-b9ed6e1a1790',
#  'TCGA-DA-A1HV',
#  'TCGA-ER-A19T',
#  'TCGA-D3-A5GL',
#  'TCGA-FS-A4F2',
#  'TCGA-EE-A2GO',
#  'TCGA-EB-A1NK',
#  'TCGA-FW-A3I3',
#  '1589f6a7-211a-458f-a2ad-72c2c175b5e5',
#  'TCGA-FS-A1ZA',
#  '166144b5-1d22-4a3a-84a9-31bc04e3560f',
#  'TCGA-EB-A3XB',
#  'TCGA-GN-A268',
#  'TCGA-D3-A1Q8',
#  'TCGA-D3-A1QA',
#  'TCGA-D3-A2JL',
#  '1a52c8ac-cabd-4623-98d8-93ee225ab57a',
#  'TCGA-BF-A5ER',
#  '1b2499f7-bb3e-472a-8216-68b2e137357c',
#  'TCGA-EE-A29P',
#  'TCGA-DA-A3F8',
#  'TCGA-D3-A51K',
#  'TCGA-D3-A5GO',
#  'TCGA-EE-A3J7',
#  '1df21d4e-5070-4d13-897a-a6f124758589',
#  'TCGA-EE-A2A1',
#  'TCGA-DA-A1HY',
#  'TCGA-FS-A1YY',
#  'TCGA-EE-A2MU',
#  'TCGA-FW-A3TV',
#  'TCGA-FR-A3R1',
#  'TCGA-EB-A42Z',
#  'TCGA-EE-A2M8',
#  'TCGA-FS-A1Z3',
#  'TCGA-FS-A1ZU',
#  'TCGA-D3-A51J',
#  'TCGA-ER-A2NF',
#  'TCGA-EE-A29E',
#  'TCGA-EE-A184',
#  'TCGA-DA-A1IB',
#  '261b4ef8-1e68-4179-826b-8c4122502df4',
#  'TCGA-EB-A3Y6',
#  'TCGA-D9-A3Z3',
#  'TCGA-D3-A2JB',
#  'TCGA-D3-A51T',
#  'TCGA-BF-A1PZ',
#  'TCGA-EE-A2GU',
#  'TCGA-ER-A19Q',
#  'TCGA-GN-A262',
#  'TCGA-FW-A3R5',
#  'TCGA-ER-A19H',
#  '2ab62da1-4896-4aab-b598-a95d033d93de',
#  'TCGA-DA-A3F5',
#  'TCGA-DA-A1I4',
#  '2d65394f-fb80-49ef-9f3e-f37f77ac404f',
#  'TCGA-FS-A4F0',
#  'TCGA-GN-A265',
#  'TCGA-BF-A3DL',
#  'TCGA-D3-A51H',
#  'TCGA-ER-A197',
#  'TCGA-ER-A19K',
#  'TCGA-EE-A2GR',
#  'TCGA-ER-A19P',
#  'TCGA-EE-A3J5',
#  'TCGA-FS-A1ZT',
#  'TCGA-FS-A1ZE',
#  '327c179d-b8d0-4e9b-9e0a-54d1b2e649b2',
#  'TCGA-EE-A2GT',
#  'TCGA-ER-A193',
#  'TCGA-EE-A2GP',
#  'TCGA-D3-A3CB',
#  'TCGA-EE-A29H',
#  'TCGA-FR-A3YN',
#  'TCGA-EE-A2MJ',
#  'TCGA-D3-A1QB',
#  'TCGA-ER-A194',
#  'TCGA-ER-A19W',
#  'TCGA-ER-A19A',
#  '38755f31-a099-45fa-bb17-d78773e405ca',
#  'TCGA-FS-A1ZY',
#  'TCGA-EE-A3JD',
#  '3b07667b-295b-41c9-a3b7-28ebb409fef1',
#  '3b2af3d9-31f1-4075-8a42-2e4f371cd0a6',
#  'TCGA-GN-A26D',
#  'TCGA-EE-A29W',
#  'TCGA-EE-A29R',
#  'TCGA-ER-A2NH',
#  'TCGA-EE-A2MN',
#  'TCGA-D3-A2J8',
#  'TCGA-ER-A2NE',
#  'TCGA-EB-A4OY',
#  'TCGA-GN-A266',
#  'TCGA-FS-A1ZG',
#  'TCGA-ER-A1A1',
#  'TCGA-ER-A19S',
#  '454aa611-1004-4e70-ba50-276f75b72113',
#  'TCGA-FW-A3TU',
#  'TCGA-FS-A1Z7',
#  'TCGA-EE-A29A',
#  'TCGA-EE-A2GL',
#  'TCGA-EE-A29G',
#  'TCGA-D3-A2JF',
#  'TCGA-EE-A3JE',
#  'TCGA-D3-A2JK',
#  'TCGA-BF-A3DJ',
#  'TCGA-FS-A1ZS',
#  '4eadf1bf-2a42-4de6-9710-86350c2fe144',
#  'TCGA-D3-A5GR',
#  'TCGA-EE-A29Q',
#  'TCGA-BF-A5EO',
#  'TCGA-ER-A19C',
#  'TCGA-D3-A2J7',
#  'TCGA-EE-A3AH',
#  'TCGA-EB-A41B',
#  'TCGA-ER-A2NG',
#  'TCGA-D3-A3ML',
#  'TCGA-EE-A3AE',
#  'TCGA-EE-A2GD',
#  'TCGA-ER-A2NF.1',
#  'TCGA-EE-A17Y',
#  'TCGA-GF-A2C7',
#  'TCGA-EB-A41A',
#  'TCGA-FS-A1ZF',
#  'TCGA-D3-A1Q4',
#  'TCGA-EE-A29X',
#  'TCGA-GN-A267',
#  'TCGA-D9-A3Z4',
#  '5a2bb92e-0429-42c3-90af-816fff63e202',
#  'TCGA-EE-A2GC',
#  'TCGA-EE-A183',
#  'TCGA-EE-A29D',
#  'TCGA-FS-A1YW',
#  'TCGA-EE-A29S',
#  'TCGA-DA-A1HW',
#  'TCGA-ER-A19T.1',
#  'TCGA-ER-A19B',
#  'TCGA-EE-A2ML',
#  'TCGA-EE-A2GI',
#  'TCGA-EE-A2A6',
#  'TCGA-ER-A195',
#  'TCGA-EB-A4IQ',
#  'TCGA-EE-A3AF',
#  'TCGA-EE-A2MK',
#  'TCGA-DA-A1I5',
#  'TCGA-EE-A2GM',
#  'TCGA-DA-A1IA',
#  'TCGA-BF-A5EQ',
#  'TCGA-FS-A1ZB',
#  'TCGA-D9-A148',
#  'TCGA-D3-A2JN',
#  'TCGA-EE-A3JA',
#  'TCGA-EB-A3HV',
#  'TCGA-D3-A3CE',
#  'TCGA-EE-A2MP',
#  '6cf6c8d5-4883-40a2-9a5c-0041f8f073de',
#  'TCGA-ER-A19M',
#  'TCGA-EB-A44R',
#  'TCGA-EE-A2MM',
#  'TCGA-FS-A1ZQ',
#  '6f7cf94c-44f1-4ad0-816b-6100e53ea887',
#  'TCGA-IH-A3EA',
#  '702fd339-2f1b-4db8-8948-8a58f69f53fb',
#  'TCGA-D3-A3C6',
#  'TCGA-ER-A2NC',
#  'TCGA-EE-A29T',
#  'TCGA-EE-A29N',
#  'TCGA-D3-A5GN',
#  'TCGA-BF-A1PX',
#  'TCGA-GN-A26A',
#  'TCGA-D3-A3MR',
#  'TCGA-D3-A3C7',
#  'TCGA-ER-A3PL',
#  'TCGA-FS-A1YX',
#  'TCGA-D9-A4Z3',
#  '7a6ac7a6-7668-42eb-a64d-7af67b3a7da3',
#  'TCGA-ER-A19E',
#  'TCGA-EE-A3AC',
#  '7cecef67-73bf-4003-821c-e42ce6adfab7',
#  'TCGA-DA-A1IC',
#  'TCGA-D3-A3MO',
#  'TCGA-ER-A196',
#  'TCGA-DA-A1I7',
#  'TCGA-EE-A2M5',
#  'TCGA-D3-A2JO',
#  'TCGA-FS-A4F5',
#  'TCGA-EB-A5FP',
#  'TCGA-D3-A1Q9',
#  'TCGA-ER-A199',
#  'TCGA-ER-A42K',
#  '88d7b0f7-b9cf-49e7-b310-900e87f7cd21',
#  'TCGA-ER-A3EV',
#  'TCGA-D3-A2JC',
#  'TCGA-EE-A2MG',
#  'TCGA-BF-A5ES',
#  'TCGA-EB-A3XC',
#  'TCGA-FW-A5DX',
#  'TCGA-D3-A51F',
#  'TCGA-FR-A2OS',
#  'TCGA-EE-A2A5',
#  '8e85bc75-8765-4c92-b167-94ed8390f5e9',
#  'TCGA-EE-A180',
#  'TCGA-EE-A2A0',
#  'TCGA-EE-A29M',
#  '904651ef-61fe-4452-b9ee-0e2821794a1e',
#  '9072817e-8a67-4f62-a0a6-8afc42b7037b',
#  '90acf286-18d7-40ff-ac1a-d56e0ced5c89',
#  'TCGA-EE-A2MH',
#  'TCGA-EE-A2MS',
#  'TCGA-DA-A1I2',
#  'TCGA-D3-A2JH',
#  'TCGA-ER-A42L',
#  'TCGA-EB-A44Q',
#  'TCGA-EE-A185',
#  'TCGA-EE-A3JH',
#  'TCGA-FS-A1ZN',
#  '973491e1-8cb1-4a4e-9df9-dc31b95804c1',
#  'TCGA-BF-A5EP',
#  'TCGA-EE-A2M7',
#  'TCGA-EE-A17X',
#  'TCGA-EB-A430',
#  'TCGA-FS-A4FC',
#  'TCGA-D3-A51N',
#  '9b4ef47f-4141-4d84-b5e8-a7b6e6c2a7ef',
#  'TCGA-FS-A1ZJ',
#  'TCGA-EE-A29B',
#  'TCGA-EE-A20F',
#  'TCGA-EE-A182',
#  'TCGA-EE-A2GB',
#  'TCGA-ER-A19L',
#  'TCGA-BF-A1PU',
#  'TCGA-EB-A5KH',
#  'TCGA-EE-A29C',
#  'TCGA-D3-A51R',
#  'TCGA-EE-A2MC',
#  'TCGA-D3-A3C8',
#  'TCGA-FS-A4F9',
#  'TCGA-D3-A2JG',
#  'TCGA-DA-A3F3',
#  'TCGA-EE-A3JB',
#  'TCGA-DA-A1I8',
#  'TCGA-BF-A1PV',
#  'TCGA-FS-A1Z4',
#  'TCGA-D3-A3MU',
#  'TCGA-DA-A1I1',
#  'TCGA-EE-A2MI',
#  'TCGA-D9-A4Z5',
#  'TCGA-EE-A2GK',
#  'TCGA-GN-A264',
#  'TCGA-FS-A4F8',
#  'TCGA-GN-A263',
#  'TCGA-EE-A3AB',
#  'TCGA-EE-A2MQ',
#  'TCGA-EB-A3XD',
#  'TCGA-EB-A3XE',
#  'TCGA-FS-A1ZH',
#  'TCGA-D3-A2JP',
#  'TCGA-EB-A44P',
#  'TCGA-ER-A19G',
#  'TCGA-EE-A3AA',
#  'TCGA-EE-A20H',
#  'TCGA-EB-A3Y7',
#  'bb63bf5c-23d6-426f-96e2-db77aff678b3',
#  'TCGA-D3-A3C3',
#  'TCGA-EE-A20B',
#  'TCGA-BF-A3DN',
#  'TCGA-GF-A3OT',
#  'TCGA-EB-A44N',
#  'TCGA-ER-A19F',
#  'c0b48dda-b719-4a9d-b732-1b0b10efd1ad',
#  'TCGA-EE-A2GJ',
#  'c170e900-9e39-4164-838a-199dcaac1463',
#  'TCGA-FS-A1ZZ',
#  'TCGA-DA-A3F2',
#  'TCGA-EE-A2ME',
#  'TCGA-EE-A3J3',
#  'TCGA-EE-A2MT',
#  'TCGA-GN-A26C',
#  'TCGA-D3-A3BZ',
#  'TCGA-EB-A42Y',
#  'TCGA-FS-A1ZR',
#  'c7abd76a-60ff-4329-b93a-2a5939c93aac',
#  'TCGA-BF-A1Q0',
#  'TCGA-EE-A2MD',
#  'TCGA-D9-A1JX',
#  'TCGA-ER-A19O',
#  'TCGA-FS-A1ZP',
#  'TCGA-EB-A44O',
#  'TCGA-BF-A3DM',
#  'TCGA-EE-A3J8',
#  'TCGA-EB-A24C',
#  'TCGA-EE-A2A2',
#  'TCGA-D3-A3CF',
#  'TCGA-FS-A1ZW',
#  'cecff6a7-eb65-4ad2-b801-11340a75d93d',
#  'TCGA-EE-A20I',
#  'TCGA-FS-A1ZK',
#  'TCGA-EB-A431',
#  'TCGA-EB-A550',
#  'TCGA-D3-A3CC',
#  'TCGA-HR-A5NC',
#  'TCGA-EB-A553',
#  'TCGA-D3-A1Q6',
#  'd48d8c30-082c-4cbe-a26e-db4f9652b5c2',
#  'TCGA-ER-A19D',
#  'TCGA-EE-A2GS',
#  'TCGA-ER-A3ES',
#  'd82ddab6-63f5-4298-bca9-4f3e690539b1',
#  'TCGA-FS-A4F4',
#  'da7b3bf7-8f1f-4776-a314-46177f73965e',
#  'daf9b208-dd9e-4281-89f6-ea9d7d0eda7e',
#  'TCGA-D3-A3MV',
#  'TCGA-EE-A3JI',
#  'TCGA-D9-A1JW',
#  'TCGA-DA-A1I0',
#  'TCGA-D3-A3C1',
#  'TCGA-EB-A299',
#  'TCGA-EE-A2MR',
#  'TCGA-EE-A2GH',
#  'TCGA-GF-A4EO',
#  'e70174b7-a2d3-4136-9da4-28a9cf123759',
#  'TCGA-ER-A198',
#  'TCGA-EB-A4IS',
#  'TCGA-D3-A2J6',
#  'TCGA-D3-A1Q1',
#  'TCGA-EE-A181',
#  'TCGA-FS-A1ZC',
#  'TCGA-ER-A42H',
#  'TCGA-EE-A29L',
#  'TCGA-D3-A2JA',
#  'ef3db400-ac1d-42e2-ad80-47cda1baa489',
#  'TCGA-D3-A2J9',
#  'TCGA-EB-A4P0',
#  'TCGA-ER-A19N',
#  'TCGA-D3-A1Q7',
#  'TCGA-ER-A3ET',
#  'f3f33ed0-a747-45dd-8999-b1a46079a6dc',
#  'TCGA-EE-A20C',
#  'TCGA-EB-A24D',
#  'TCGA-EB-A551',
#  'TCGA-EB-A4XL',
#  'TCGA-FR-A3YO',
#  'TCGA-EE-A2MF',
#  'TCGA-D3-A1Q5',
#  'TCGA-FS-A4FB',
#  'TCGA-D3-A2JD',
#  'TCGA-D9-A149',
#  'TCGA-EE-A3AG',
#  'TCGA-D9-A4Z2',
#  'TCGA-EB-A4OZ',
#  'TCGA-EE-A3J4',
#  'TCGA-FS-A1ZM',
#  'TCGA-D3-A5GS',
#  'TCGA-EB-A3XF',
#  'TCGA-EE-A2GE',
#  'ff7431a9-243a-4651-80bb-096379925bbe']

# %%
#정규화 과정을 거치기 위해 유전정보의 길이가 필요하다

with open ("genes.csv","r") as f:
    gene_info=pd.read_csv(f,index_col=0)
gene_info.head(5)

#유전자의 이름을 index로 지정한다
# Out:
#             GeneID  GeneLength
# GeneSymbol
# CPA1          1357        1724
# GUCY2D        3000        3623
# UBC           7316        2687
# C11orf95     65998        5581
# ANKMY2       57037        2611

# %%
#유전자의 길이 데이터에는 실제 실험에서 측정한 것보다 더 많은 유전자가 포함된다

print("data_table는 측정 길이 유전자",data_table.shape[0]) #유전자의 측정길이 데이터
print("gene_info는 실제 길이 유전자",gene_info.shape[0])  #유전자의 실제길이 데이터
# Out:
# data_table는 측정 길이 유전자 20500
# gene_info는 실제 길이 유전자 20503

# %%
# 서로 연관된 유전자를 얻기 위해 필터를 적용해보자


matched_index=pd.Index.intersection(data_table.index, gene_info.index)

# %%
# 각 개체의 각 유전자에 대한 발현 수를 포함하는 2차원 ndarray

counts=np.asarray(data_table.loc[matched_index],dtype=int)
gene_names=np.array(matched_index)

# %%
gene_names
# Out:
# array(['A1BG', 'A1CF', 'A2BP1', ..., 'ZZZ3', 'psiTPTE22', 'tAKR'],
#       dtype=object)

# %%
#유전자수와개체 수 확인


print(f'{counts.shape[1]} 개의 개체에 {counts.shape[0]}개의 유전자가 측정됨')
# Out:
# 375 개의 개체에 20500개의 유전자가 측정됨

# %% [markdown]
# # 개체당 유전자 발현의 수를 정규화

# %%
#이제유전자 수 분포 그래프를 그려보자


total_counts=np.sum(counts,axis=0)


# 커널 밀도 추정을 사용한다
density=stats.kde.gaussian_kde(total_counts)
# 측정 범위를 지정한다

x=np.arange(min(total_counts),max(total_counts),10000)

#밀도 그래프 생성
fig,ax=plt.subplots()
ax.plot(x,density(x))
ax.set_xlabel("개체당 유전자 발현 수")
ax.set_ylabel("밀도")


plt.show()

# %% [markdown]
# ## 샘플 간 공간 크기의 정규화

# %%
# 그래프를 위한 하위데이터

np.random.seed(seed=7)

# 무작위적으로 70개를 선택

samples_index=np.random.choice(range(counts.shape[1]),size=70,replace=False)
counts_subset=counts[:,samples_index]

# 그래프를 읽기 쉽게 만들기 위한 사용자 정의 x축 레이블



def reduce_xaxis_labels(ax,factor):
    """ x축에 밀집되지 않도로 i 번째 레이블만 표시한다
        factor: x축 레이블 수를 줄이기 위한 정수"""
    plt.setp(ax.xaxis.get_ticklabels(),visible=False)
    for label in ax.xaxis.get_ticklabels()[factor-1::factor]:
        label.set_visible(True)
        
        
        
# 개체별 발현 수 막대 그래프


fig, ax = plt.subplots(figsize=(6, 4))

with plt.style.context('style/thinner.mplstyle'):
    ax.boxplot(counts_subset)
    ax.set_xlabel("Individuals")
    ax.set_ylabel("Gene expression counts")
    reduce_xaxis_labels(ax, 5)

# %%
fig, ax = plt.subplots(figsize=(6, 4))

with plt.style.context('style/thinner.mplstyle'):
    ax.boxplot(np.log(counts_subset+1))
    ax.set_xlabel("Individuals")
    ax.set_ylabel("Gene expression counts(log)")
    reduce_xaxis_labels(ax, 5)

# %%
# Normalize by library size
# Divide the expression counts by the total counts for that individual
# Multiply by 1 million to get things back in a similar scale
counts_lib_norm = counts / total_counts * 1000000
# Notice how we just used broadcasting twice there!
counts_subset_lib_norm = counts_lib_norm[:,samples_index]

# Bar plot of expression counts by individual
fig, ax = plt.subplots(figsize=(6, 4))

with plt.style.context('style/thinner.mplstyle'):
    ax.boxplot(np.log(counts_subset_lib_norm + 1))
    ax.set_xlabel("Individuals")
    ax.set_ylabel("log gene expression counts")
    reduce_xaxis_labels(ax, 5)

# %%
import itertools as it
from collections import defaultdict


def class_boxplot(data, classes, colors=None, **kwargs):
    """Make a boxplot with boxes colored according to the class they belong to.

    Parameters
    ----------
    data : list of array-like of float
        The input data. One boxplot will be generated for each element
        in `data`.
    classes : list of string, same length as `data`
        The class each distribution in `data` belongs to.

    Other parameters
    ----------------
    kwargs : dict
        Keyword arguments to pass on to `plt.boxplot`.
    """
    all_classes = sorted(set(classes))
    colors = plt.rcParams['axes.prop_cycle'].by_key()['color']
    class2color = dict(zip(all_classes, it.cycle(colors)))

    # map classes to data vectors
    # other classes get an empty list at that position for offset
    class2data = defaultdict(list)
    for distrib, cls in zip(data, classes):
        for c in all_classes:
            class2data[c].append([])
        class2data[cls][-1] = distrib

    # then, do each boxplot in turn with the appropriate color
    fig, ax = plt.subplots()
    lines = []
    for cls in all_classes:
        # set color for all elements of the boxplot
        for key in ['boxprops', 'whiskerprops', 'flierprops']:
            kwargs.setdefault(key, {}).update(color=class2color[cls])
        # draw the boxplot
        box = ax.boxplot(class2data[cls], **kwargs)
        lines.append(box['whiskers'][0])
    ax.legend(lines, all_classes)
    return ax

# %%
log_counts_3 = list(np.log(counts.T[:3] + 1))
log_ncounts_3 = list(np.log(counts_lib_norm.T[:3] + 1))
ax = class_boxplot(log_counts_3 + log_ncounts_3,
                   ['raw counts'] * 3 + ['normalized by library size'] * 3,
                   labels=[1, 2, 3, 1, 2, 3])
ax.set_xlabel('sample number')
ax.set_ylabel('log gene expression counts');
