# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen

import re

# %%
url="https://finance.naver.com/marketindex"
page=urlopen(url)

soup=BeautifulSoup(page,"html.parser")

print(soup.prettify)
# Out:
# <bound method Tag.prettify of
# <script language="javascript" src="/template/head_js.nhn?referer=info.finance.naver.com&amp;menu=marketindex&amp;submenu=market"></script>
# <script src="/js/info/jindo.min.ns.1.5.3.euckr.js" type="text/javascript"></script>
# <script src="/js/jindo.1.5.3.element-text-patch.js" type="text/javascript"></script>
# <div id="container" style="padding-bottom:0px;">
# <script language="JavaScript" src="/js/flashObject.js?20190730011942"></script>
# <div class="market_include">
# <div class="market_data">
# <div class="market1">
# <div class="title">
# <h2 class="h_market1"><span>환전 고시 환율</span></h2>
# </div>
# <!-- data -->
# <div class="data">
# <ul class="data_lst" id="exchangeList">
# <li class="on">
# <a class="head usd" href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_USDKRW" onclick="clickcr(this, 'fr1.usdt', '', '', event);">
# <h3 class="h_lst"><span class="blind">미국 USD</span></h3>
# <div class="head_info point_dn">
# ...

# %%
soup.find_all("span","value")[0].string
# Out:
# '1,214.60'

# %%
url="https://www.chicagomag.com/Where-to-Eat-in-Chicago-Right-Now/"


html=urlopen(url)
soup=BeautifulSoup(html, "html.parser")

soup
# Out:
# <!DOCTYPE doctype html>
#
# <html lang="en">
# <head>
# <!-- Urbis magnitudo. Fabulas magnitudo. -->
# <meta charset="utf-8"/>
# <style>a.edit_from_site {display: none !important;}</style>
# <title>
#   The 10 Hottest Restaurants in Chicago Right Now |
#   Chicago magazine
#     </title>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable = no" name="viewport">
# <meta content="The city’s most buzzed-about restaurants this month" name="description"/>
# <!-- <meta name="description" content="The city’s most buzzed-about restaurants this month"> -->
# <meta content="Café Cancale, The Purple Pig, Bad Hunter, The Licking, Flora Fauna, Graze x Ingrained, Kinton Ramen, Maddon’s Post, 3 Floyds Distillery, City Hall, hot list, chicago restaurants, chicago restaurant, restaurants, restaurant, where to eat in chicago" name="keywords"/>
# <meta content="37873197144" property="fb:pages">
# <link href="//www.googletagservices.com" rel="dns-prefetch"/>
# ...

# %%
print(soup.find_all("div","hotlist-item"))
# Out:
# [<div class="hotlist-item" id="hotlist-item-1">
# <h2 class="hotlist-name"><span class="hotlist-counter">1</span>Café Cancale</h2>
# <figure>
# <figcaption>
# <div class="hotlist-caption">
# <span class="leadin">What:</span>A bit of Brittany, courtesy of Paul Kahan and company<br/>
# <span class="leadin">Why:</span>After enough plates of oysters and clams, you’ll swear you can smell the ocean on the Milwaukee Avenue breeze.<br/>
# <a href="http://www.chicagomag.com/dining-drinking/May-2019/Say-Bonjour-to-Caf-Cancale/#/0">Read more</a> about new Wicker Park spot.
# <div><span class="leadin">Where:</span><em>1576 N. Milwaukee Ave., Wicker Park <a href="https://www.cafecancale.com/">Website</a></em></div>
# <a class="hotlist-next" href="javascript:void(0);" onclick="jumpto('#hotlist-item-2',150); ga('send',  'event', 'Interaction', 'Hotlist next icon ' + 1,'/Where-to-Eat-in-Chicago-Right-Now/')">Next</a>
# </div>
# <div class="hotlist-photo-outer">
# ...

# %%
len(soup.find_all("div","hotlist-item"))
# Out:
# 10

# %%
print(soup.find_all("div","hotlist-item")[0])    #1위인 맛집의 태그 추출
# Out:
# <div class="hotlist-item" id="hotlist-item-1">
# <h2 class="hotlist-name"><span class="hotlist-counter">1</span>Café Cancale</h2>
# <figure>
# <figcaption>
# <div class="hotlist-caption">
# <span class="leadin">What:</span>A bit of Brittany, courtesy of Paul Kahan and company<br/>
# <span class="leadin">Why:</span>After enough plates of oysters and clams, you’ll swear you can smell the ocean on the Milwaukee Avenue breeze.<br/>
# <a href="http://www.chicagomag.com/dining-drinking/May-2019/Say-Bonjour-to-Caf-Cancale/#/0">Read more</a> about new Wicker Park spot.
# <div><span class="leadin">Where:</span><em>1576 N. Milwaukee Ave., Wicker Park <a href="https://www.cafecancale.com/">Website</a></em></div>
# <a class="hotlist-next" href="javascript:void(0);" onclick="jumpto('#hotlist-item-2',150); ga('send',  'event', 'Interaction', 'Hotlist next icon ' + 1,'/Where-to-Eat-in-Chicago-Right-Now/')">Next</a>
# </div>
# <div class="hotlist-photo-outer">
# ...

# %% [markdown]
# # 3-4 접근한 웹페이지에서 원하는 데이터 추출하고 정리하기

# %%
tmp_one=soup.find_all("div","hotlist-item")[1]
tmp_one
# Out:
# <div class="hotlist-item" id="hotlist-item-2">
# <h2 class="hotlist-name"><span class="hotlist-counter">2</span>The Purple Pig</h2>
# <figure>
# <figcaption>
# <div class="hotlist-caption">
# <span class="leadin">What:</span>The reigning king of charcuterie<br/>
# <span class="leadin">Why:</span>The Michigan Avenue magnet finally moved to a bigger space down the street. Maybe now you’ll be able to get a seat.
# <div><span class="leadin">Where:</span><em>444 N. Michigan Ave., Near North Side <a href="https://www.thepurplepigchicago.com/">Website</a></em></div>
# <a class="hotlist-next" href="javascript:void(0);" onclick="jumpto('#hotlist-item-3',150); ga('send',  'event', 'Interaction', 'Hotlist next icon ' + 2,'/Where-to-Eat-in-Chicago-Right-Now/')">Next</a>
# </div>
# <div class="hotlist-photo-outer">
# ...

# %%
temp_one=soup.find_all("div","hotlist-item")
len(temp_one)
# Out:
# 10

# %%
tmp_one.find(class_="hotlist-name").get_text()[1:]
# Out:
# 'The Purple Pig'

# %%
tmp_one.find(class_="hotlist-counter").get_text()
# Out:
# '2'

# %%
tmp_one.find("em").get_text()
# Out:
# '444 N. Michigan Ave., Near North Side Website'

# %%
rank=[]
cafe_name=[]
address=[]
list_soup = soup.find_all("div","hotlist-item")


for item in list_soup:
    rank.append(item.find(class_ = "hotlist-counter").get_text())
    cafe_name.append(item.find(class_ = "hotlist-name").get_text())
 
 
    

cafe_name
# Out:
# ['1Café Cancale',
#  '2The Purple Pig',
#  '3Bad Hunter',
#  '4The Licking',
#  '5Flora Fauna',
#  '6Graze x Ingrained',
#  '7Kinton Ramen',
#  '8Maddon’s Post',
#  '93 Floyds Distillery',
#  '10City Hall']
